# %% [markdown]
# In this exercise, you will use Aequitas to investigate the potential bias in a model/data set.
#
# - We'll use the Car Evaluation Data Set from the UCI Machine Learning Repository(https://archive.ics.uci.edu/ml/datasets/Car+Evaluation), a notebook that trains a logistic regression model to determine the car's acceptability is provided.
# - Using Aequitas (e-kai-tas), determine if the model contains bias. For simplicity, from Aequitas' Fairness class obtain the results of the get_overall_fairness method which returns a dictionary with Yes/No result for "Unsupervised Fairness", "Supervised Fairness" and "Overall Fairness".
# - Lastly, use the aequitas.plotting.Plot module and compute the summary on fpr, fnr, and for with a 1.25 fairness_threshold.
# - You can draw inspiration from examples present here: https://github.com/dssg/aequitas/blob/master/docs/source/examples/compas_demo.ipynb

# %% [markdown]
# The data from this exercise comes from the UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Car+Evaluation For more details on the data set see the included documentation.

# %%
# To run in jupyter notebook: 
# 1. Open terminal in current folder
# 2. Run jupyter-lab

# %%
# Ensure that Aequitas dependency is installed
import sys
#!{sys.executable} -m pip install --upgrade pip setuptools wheel
# !{sys.executable} -m pip install aequitas==0.42
# Out:
# Requirement already satisfied: aequitas==0.42 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (0.42.0)
# Requirement already satisfied: ohio>=0.2.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.5.0)
# Requirement already satisfied: Flask==0.12.2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.12.2)
# Requirement already satisfied: Flask-Bootstrap==3.3.7.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (3.3.7.1)
# Requirement already satisfied: markdown2==2.3.5 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (2.3.5)
# Requirement already satisfied: matplotlib>=3.0.3 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (3.10.6)
# Requirement already satisfied: pandas>=0.24.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (2.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.1.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (2.0.43)
# Requirement already satisfied: tabulate==0.8.2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.8.2)
# Requirement already satisfied: xhtml2pdf==0.2.2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.2.2)
# Requirement already satisfied: seaborn>=0.9.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.13.2)
# Requirement already satisfied: altair==4.1.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (4.1.0)
# Requirement already satisfied: millify==0.1.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from aequitas==0.42) (0.1.1)
# Requirement already satisfied: entrypoints in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from altair==4.1.0->aequitas==0.42) (0.4)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from altair==4.1.0->aequitas==0.42) (3.1.4)
# Requirement already satisfied: jsonschema in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from altair==4.1.0->aequitas==0.42) (4.23.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from altair==4.1.0->aequitas==0.42) (1.26.4)
# Requirement already satisfied: toolz in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from altair==4.1.0->aequitas==0.42) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from Flask==0.12.2->aequitas==0.42) (3.0.6)
# Requirement already satisfied: click>=2.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from Flask==0.12.2->aequitas==0.42) (8.1.7)
# Requirement already satisfied: itsdangerous>=0.21 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from Flask==0.12.2->aequitas==0.42) (2.2.0)
# Requirement already satisfied: dominate in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from Flask-Bootstrap==3.3.7.1->aequitas==0.42) (2.9.1)
# Requirement already satisfied: visitor in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from Flask-Bootstrap==3.3.7.1->aequitas==0.42) (0.1.3)
# Requirement already satisfied: html5lib>=1.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (1.1)
# Requirement already satisfied: httplib2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (0.31.0)
# Requirement already satisfied: pyPdf2 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (3.0.1)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (11.1.0)
# Requirement already satisfied: reportlab>=3.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (4.4.7)
# Requirement already satisfied: six in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from xhtml2pdf==0.2.2->aequitas==0.42) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from html5lib>=1.0->xhtml2pdf==0.2.2->aequitas==0.42) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from jinja2->altair==4.1.0->aequitas==0.42) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from matplotlib>=3.0.3->aequitas==0.42) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from pandas>=0.24.1->aequitas==0.42) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from pandas>=0.24.1->aequitas==0.42) (2024.2)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from reportlab>=3.0->xhtml2pdf==0.2.2->aequitas==0.42) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from SQLAlchemy>=1.1.1->aequitas==0.42) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/udacity/lib/python3.10/site-packages (from jsonschema->altair==4.1.0->aequitas==0.42) (0.22.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
from aequitas.plotting import Plot
ap = Plot()
import pandas as pd
import warnings

from aequitas.group import Group
from aequitas.bias import Bias 
from aequitas.fairness import Fairness

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, label_binarize, LabelBinarizer
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
# Suppress FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [raw]
# CAR                      car acceptability
# . PRICE                  overall price
# . . buying               buying price
# . . maint                price of the maintenance
# . TECH                   technical characteristics
# . . COMFORT              comfort
# . . . doors              number of doors
# . . . persons            capacity in terms of persons to carry
# . . . lug_boot           the size of luggage boot
# . . safety               estimated safety of the car

# %%
# I manually added the headers to the data set.
df = pd.read_csv("./car.csv")

display(df.head())
display(df['car'].unique())
display(df.shape)
# Out:
#   buying  maint doors persons lug_boot safety    car
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc
# array(['unacc', 'acc', 'vgood', 'good'], dtype=object)
# (1728, 7)

# %%
# We'll modify the data to make it a binary problem of acceptable or unacceptable car.
df = df.where(df != 'good', 'acc')
df = df.where(df != 'vgood', 'acc')

y = df.pop('car')
X = df

df.head()
# Out:
#   buying  maint doors persons lug_boot safety
# 0  vhigh  vhigh     2       2    small    low
# 1  vhigh  vhigh     2       2    small    med
# 2  vhigh  vhigh     2       2    small   high
# 3  vhigh  vhigh     2       2      med    low
# 4  vhigh  vhigh     2       2      med    med

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=23)
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)

# Use this later to construct the DataFrame Aequitas requires.
df_aq = X_test.reset_index(drop=True).copy()

#ohe = OneHotEncoder(handle_unknown="ignore", sparse=False)
ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=False)
X_train = ohe.fit_transform(X_train.values)
X_test = ohe.transform(X_test.values)

lb = LabelBinarizer()
y_train = label_binarize(y_train.values, classes=['unacc', 'acc']).ravel()
y_test = label_binarize(y_test.values, classes=['unacc', 'acc']).ravel()
# Out:
# X_train shape:  (1296, 6)
# X_test shape:  (432, 6)

# %%
display(X_train.shape)
# Out:
# (1296, 21)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)

scores = lr.predict_proba(X_test)
pred = lr.predict(X_test)

f1 = f1_score(y_test, pred)
print(f"F1 score: {f1:.4f}")
# Out:
# F1 score: 0.8960

# %%
cm = confusion_matrix(y_test, pred, labels=[0, 1])
ConfusionMatrixDisplay(cm, display_labels=["unacc", "acc"]).plot()

# %%
# Construct the dataframe that Aequitas [e-kai-tas] will use.
# You can draw inspiration from examples present here: https://github.com/dssg/aequitas/blob/master/docs/source/examples/compas_demo.ipynb 
df_aq["label_value"] = y_test
df_aq["score"] = pred
df_aq.head()
# Out:
#   buying  maint  doors persons lug_boot safety  label_value  score
# 0    med    low  5more       4    small    low            0      0
# 1   high  vhigh      3    more    small    low            0      0
# 2    low    low      4       4      med   high            1      1
# 3    low   high      3       4      med    med            1      1
# 4  vhigh   high  5more       4      big   high            0      1

# %%
# Run Aequitas.
# Summarize: Aequitas classes provides a few functions that provide a high level summary of fairness and disparity, such as 
# plot_fairness_group_all()
# plot_fairness_disparity_all()
# plot_disparity_all()

# %% [markdown]
# It is always a good idea to see how predictions are distributed across the categories of features. For example, for cars that can seat only 2 persons are always correctly classified as unacceptable. Cars that have low safety are also always classified as unacceptable.
#
# This can cause some statistics (`False Positive Rate`, `False Negative Rate`) to be zero or NAN because there are no false positives or false negatives.
#
# For the `persons` column, we can show this behavior below.

# %%
# The pandas.crosstab() function is used to compute a cross-tabulation of two (or more) factors. 
# It is a way to summarize the relationship between categorical variables in a tabular format, 
# showing the frequency (or other aggregation) of combinations of values.

# predicted labels
pd.crosstab(df_aq.score, df_aq.persons)
# Out:
# persons    2   4  more
# score
# 0        143  79    79
# 1          0  70    61

# %%
# true labels
pd.crosstab(df_aq.label_value, df_aq.persons)
# Out:
# persons        2   4  more
# label_value
# 0            143  87    83
# 1              0  62    57

# %%
# select predictions where 
y_test_person_eq_2 = y_test[df_aq.loc[df_aq.persons == "2"].index]
y_pred_person_eq_2 = pred[df_aq.loc[df_aq.persons == "2"].index]

# %%
cm_person_eq_2 = confusion_matrix(y_test_person_eq_2, y_pred_person_eq_2, labels=[0, 1])
ConfusionMatrixDisplay(cm_person_eq_2, display_labels=["unacc", "acc"]).plot()

# %% [markdown]
# ## Group

# %%
# Run Aequitas.
group = Group()
xtab, idxs = group.get_crosstabs(df_aq)
xtab.head()
# Out:
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  131         buying            high  0.913043
# 1         0      binary 0/1  131         buying             low  0.972973
# 2         0      binary 0/1  131         buying             med  1.000000
# 3         0      binary 0/1  131         buying           vhigh  0.777778
# 4         0      binary 0/1  131          maint            high  0.896552
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.900000  0.024096  0.300000  0.100000  0.086957  0.975904   0.700000  30
# 1  0.963636  0.018519  0.052632  0.036364  0.027027  0.981481   0.947368  38
# 2  0.946667  0.000000  0.088889  0.053333  0.000000  1.000000   0.911111  45
# 3  0.956989  0.043011  0.222222  0.043011  0.222222  0.956989   0.777778  18
# 4  0.929412  0.036585  0.187500  0.070588  0.103448  0.963415   0.812500  32
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  83  0.229008  0.265487   9   2  81  21               23               90
# 1  54  0.290076  0.413043   2   1  53  36               37               55
# 2  71  0.343511  0.387931   4   0  71  41               41               75
# 3  93  0.137405  0.162162   4   4  89  14               18               93
# 4  82  0.244275  0.280702   6   3  79  26               29               85
#
#    group_size  total_entities      prev
# 0         113             432  0.203540
# 1          92             432  0.402174
# 2         116             432  0.353448
# 3         111             432  0.162162
# 4         114             432  0.254386

# %% [markdown]
# ## Bias

# %%
bias = Bias()
bias_df = bias.get_disparity_major_group(xtab, original_df=df_aq, alpha=0.05, mask_significance=True)
bias_df.head()
# Out:
# get_disparity_major_group()
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  131         buying            high  0.913043
# 1         0      binary 0/1  131         buying             low  0.972973
# 2         0      binary 0/1  131         buying             med  1.000000
# 3         0      binary 0/1  131         buying           vhigh  0.777778
# 4         0      binary 0/1  131          maint            high  0.896552
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.900000  0.024096  0.300000  0.100000  0.086957  0.975904   0.700000  30
# 1  0.963636  0.018519  0.052632  0.036364  0.027027  0.981481   0.947368  38
# 2  0.946667  0.000000  0.088889  0.053333  0.000000  1.000000   0.911111  45
# 3  0.956989  0.043011  0.222222  0.043011  0.222222  0.956989   0.777778  18
# 4  0.929412  0.036585  0.187500  0.070588  0.103448  0.963415   0.812500  32
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  83  0.229008  0.265487   9   2  81  21               23               90
# 1  54  0.290076  0.413043   2   1  53  36               37               55
# 2  71  0.343511  0.387931   4   0  71  41               41               75
# 3  93  0.137405  0.162162   4   4  89  14               18               93
# 4  82  0.244275  0.280702   6   3  79  26               29               85
#
#    group_size  total_entities      prev  ppr_disparity  pprev_disparity  \
# 0         113             432  0.203540       0.666667         0.684366
# 1          92             432  0.402174       0.844444         1.064734
# 2         116             432  0.353448       1.000000         1.000000
# 3         111             432  0.162162       0.400000         0.418018
# 4         114             432  0.254386       1.000000         1.000000
#
#    precision_disparity  fdr_disparity  for_disparity  fpr_disparity  \
# 0             0.768293       3.375000           10.0       1.875000
# 1             1.039795       0.592105           10.0       0.681818
# 2             1.000000       1.000000            NaN       1.000000
# 3             0.853659       2.500000           10.0       0.806452
# 4             1.000000       1.000000            1.0       1.000000
#
#    fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0           10.0       0.913043       0.950704       0.975904
# 1           10.0       0.972973       1.017926       0.981481
# 2            NaN       1.000000       1.000000       1.000000
# 3           10.0       0.777778       1.010904       0.956989
# 4            1.0       1.000000       1.000000       1.000000
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0                 med                   med                       med
# 1                 med                   med                       med
# 2                 med                   med                       med
# 3                 med                   med                       med
# 4                high                  high                      high
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0                 med                 med                 med
# 1                 med                 med                 med
# 2                 med                 med                 med
# 3                 med                 med                 med
# 4                high                high                high
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0                 med                 med                 med
# 1                 med                 med                 med
# 2                 med                 med                 med
# 3                 med                 med                 med
# 4                high                high                high
#
#   npv_ref_group_value
# 0                 med
# 1                 med
# 2                 med
# 3                 med
# 4                high

# %% [markdown]
# ## Fairness

# %%
fairness = Fairness()
fairness_df = fairness.get_group_value_fairness(bias_df)
fairness_df.head()
# Out:
#    model_id score_threshold    k attribute_name attribute_value       tpr  \
# 0         0      binary 0/1  131         buying            high  0.913043
# 1         0      binary 0/1  131         buying             low  0.972973
# 2         0      binary 0/1  131         buying             med  1.000000
# 3         0      binary 0/1  131         buying           vhigh  0.777778
# 4         0      binary 0/1  131          maint            high  0.896552
#
#         tnr       for       fdr       fpr       fnr       npv  precision  pp  \
# 0  0.900000  0.024096  0.300000  0.100000  0.086957  0.975904   0.700000  30
# 1  0.963636  0.018519  0.052632  0.036364  0.027027  0.981481   0.947368  38
# 2  0.946667  0.000000  0.088889  0.053333  0.000000  1.000000   0.911111  45
# 3  0.956989  0.043011  0.222222  0.043011  0.222222  0.956989   0.777778  18
# 4  0.929412  0.036585  0.187500  0.070588  0.103448  0.963415   0.812500  32
#
#    pn       ppr     pprev  fp  fn  tn  tp  group_label_pos  group_label_neg  \
# 0  83  0.229008  0.265487   9   2  81  21               23               90
# 1  54  0.290076  0.413043   2   1  53  36               37               55
# 2  71  0.343511  0.387931   4   0  71  41               41               75
# 3  93  0.137405  0.162162   4   4  89  14               18               93
# 4  82  0.244275  0.280702   6   3  79  26               29               85
#
#    group_size  total_entities      prev  ppr_disparity  pprev_disparity  \
# 0         113             432  0.203540       0.666667         0.684366
# 1          92             432  0.402174       0.844444         1.064734
# 2         116             432  0.353448       1.000000         1.000000
# 3         111             432  0.162162       0.400000         0.418018
# 4         114             432  0.254386       1.000000         1.000000
#
#    precision_disparity  fdr_disparity  for_disparity  fpr_disparity  \
# 0             0.768293       3.375000           10.0       1.875000
# 1             1.039795       0.592105           10.0       0.681818
# 2             1.000000       1.000000            NaN       1.000000
# 3             0.853659       2.500000           10.0       0.806452
# 4             1.000000       1.000000            1.0       1.000000
#
#    fnr_disparity  tpr_disparity  tnr_disparity  npv_disparity  \
# 0           10.0       0.913043       0.950704       0.975904
# 1           10.0       0.972973       1.017926       0.981481
# 2            NaN       1.000000       1.000000       1.000000
# 3           10.0       0.777778       1.010904       0.956989
# 4            1.0       1.000000       1.000000       1.000000
#
#   ppr_ref_group_value pprev_ref_group_value precision_ref_group_value  \
# 0                 med                   med                       med
# 1                 med                   med                       med
# 2                 med                   med                       med
# 3                 med                   med                       med
# 4                high                  high                      high
#
#   fdr_ref_group_value for_ref_group_value fpr_ref_group_value  \
# 0                 med                 med                 med
# 1                 med                 med                 med
# 2                 med                 med                 med
# 3                 med                 med                 med
# 4                high                high                high
#
#   fnr_ref_group_value tpr_ref_group_value tnr_ref_group_value  \
# 0                 med                 med                 med
# 1                 med                 med                 med
# 2                 med                 med                 med
# 3                 med                 med                 med
# 4                high                high                high
#
#   npv_ref_group_value  Statistical Parity  Impact Parity FDR Parity  \
# 0                 med               False          False      False
# 1                 med                True           True      False
# 2                 med                True           True       True
# 3                 med               False          False      False
# 4                high                True           True       True
#
#    FPR Parity FOR Parity FNR Parity TPR Parity  TNR Parity  NPV Parity  \
# 0       False      False      False       True        True        True
# 1       False      False      False       True        True        True
# 2        True        NaN        NaN       True        True        True
# 3        True      False      False      False        True        True
# 4        True       True       True       True        True        True
#
#   Precision Parity  TypeI Parity TypeII Parity  Equalized Odds  \
# 0            False         False         False           False
# 1             True         False         False           False
# 2             True          True           NaN            True
# 3             True         False         False           False
# 4             True          True          True            True
#
#    Unsupervised Fairness  Supervised Fairness
# 0                  False                False
# 1                   True                False
# 2                   True                False
# 3                  False                False
# 4                   True                 True

# %%
overall_fairness = fairness.get_overall_fairness(fairness_df)
print(overall_fairness)
# Out:
# {'Unsupervised Fairness': False, 'Supervised Fairness': False, 'Overall Fairness': False}

# %%
metrics = ['fpr', "for", "fnr"]
disparity_metrics = [f"{metric}_disparity" for metric in metrics]

# %%
# Just as we discussed above, some statistics are zero or NAN
bias_df[["attribute_name", "attribute_value"] + metrics + disparity_metrics]
# Out:
#    attribute_name attribute_value       fpr       for       fnr  \
# 0          buying            high  0.100000  0.024096  0.086957
# 1          buying             low  0.036364  0.018519  0.027027
# 2          buying             med  0.053333  0.000000  0.000000
# 3          buying           vhigh  0.043011  0.043011  0.222222
# 4           maint            high  0.070588  0.036585  0.103448
# 5           maint             low  0.083333  0.029412  0.051282
# 6           maint             med  0.076923  0.032258  0.052632
# 7           maint           vhigh  0.021978  0.000000  0.000000
# 8           doors               2  0.061728  0.037975  0.150000
# 9           doors               3  0.062500  0.038462  0.078947
# 10          doors               4  0.061728  0.000000  0.000000
# 11          doors           5more  0.056338  0.014706  0.031250
# 12        persons               2  0.000000  0.000000       NaN
# 13        persons               4  0.126437  0.037975  0.048387
# 14        persons            more  0.096386  0.050633  0.070175
# 15       lug_boot             big  0.022727  0.022727  0.045455
# 16       lug_boot             med  0.067308  0.020202  0.040816
# 17       lug_boot           small  0.082645  0.026316  0.115385
# 18         safety            high  0.088235  0.031250  0.028986
# 19         safety             low  0.000000  0.000000       NaN
# 20         safety             med  0.132653  0.055556  0.100000
#
#     fpr_disparity  for_disparity  fnr_disparity
# 0        1.875000      10.000000      10.000000
# 1        0.681818      10.000000      10.000000
# 2        1.000000            NaN            NaN
# 3        0.806452      10.000000      10.000000
# 4        1.000000       1.000000       1.000000
# 5        1.180556       0.803922       0.495726
# 6        1.089744       0.881720       0.508772
# 7        0.311355       0.000000       0.000000
# 8        0.987654       0.987342       1.900000
# 9        1.000000       1.000000       1.000000
# 10       0.987654       0.000000       0.000000
# 11       0.901408       0.382353       0.395833
# 12       0.000000       0.000000            NaN
# 13       1.000000       1.000000       1.000000
# 14       0.762322       1.333333       1.450292
# 15       0.337662       1.125000       1.113636
# 16       1.000000       1.000000       1.000000
# 17       1.227863       1.302632       2.826923
# 18       0.665158       0.562500       0.289855
# 19       0.000000       0.000000            NaN
# 20       1.000000       1.000000       1.000000

# %%
# To avoid issues when plotting, add an epilon (0.000001) to cases where statistics are zero or NAN
eps = 0.000001
bias_df[disparity_metrics] = bias_df[disparity_metrics].fillna(0.0) + eps

# %%
bias_df[["attribute_name", "attribute_value"] + metrics + disparity_metrics]
# Out:
#    attribute_name attribute_value       fpr       for       fnr  \
# 0          buying            high  0.100000  0.024096  0.086957
# 1          buying             low  0.036364  0.018519  0.027027
# 2          buying             med  0.053333  0.000000  0.000000
# 3          buying           vhigh  0.043011  0.043011  0.222222
# 4           maint            high  0.070588  0.036585  0.103448
# 5           maint             low  0.083333  0.029412  0.051282
# 6           maint             med  0.076923  0.032258  0.052632
# 7           maint           vhigh  0.021978  0.000000  0.000000
# 8           doors               2  0.061728  0.037975  0.150000
# 9           doors               3  0.062500  0.038462  0.078947
# 10          doors               4  0.061728  0.000000  0.000000
# 11          doors           5more  0.056338  0.014706  0.031250
# 12        persons               2  0.000000  0.000000       NaN
# 13        persons               4  0.126437  0.037975  0.048387
# 14        persons            more  0.096386  0.050633  0.070175
# 15       lug_boot             big  0.022727  0.022727  0.045455
# 16       lug_boot             med  0.067308  0.020202  0.040816
# 17       lug_boot           small  0.082645  0.026316  0.115385
# 18         safety            high  0.088235  0.031250  0.028986
# 19         safety             low  0.000000  0.000000       NaN
# 20         safety             med  0.132653  0.055556  0.100000
#
#     fpr_disparity  for_disparity  fnr_disparity
# 0        1.875001      10.000001      10.000001
# 1        0.681819      10.000001      10.000001
# 2        1.000001       0.000001       0.000001
# 3        0.806453      10.000001      10.000001
# 4        1.000001       1.000001       1.000001
# 5        1.180557       0.803923       0.495727
# 6        1.089745       0.881721       0.508773
# 7        0.311356       0.000001       0.000001
# 8        0.987655       0.987343       1.900001
# 9        1.000001       1.000001       1.000001
# 10       0.987655       0.000001       0.000001
# 11       0.901409       0.382354       0.395834
# 12       0.000001       0.000001       0.000001
# 13       1.000001       1.000001       1.000001
# 14       0.762323       1.333334       1.450293
# 15       0.337663       1.125001       1.113637
# 16       1.000001       1.000001       1.000001
# 17       1.227864       1.302633       2.826924
# 18       0.665159       0.562501       0.289856
# 19       0.000001       0.000001       0.000001
# 20       1.000001       1.000001       1.000001

# %%
disparity_tolerance = 1.25

# Deprecated function summary()
# ap.summary(bias_df, metrics, fairness_threshold=disparity_tolerance)

# Aequitas Fairness() class provides a few functions that provide a high level summary of fairness and disparity, such as 
# plot_fairness_group()
# plot_fairness_group_all()
# plot_fairness_disparity()
# plot_fairness_disparity_all()
# plot_disparity()
# See some example here: https://github.com/dssg/aequitas/blob/master/docs/source/examples/compas_demo.ipynb 
p = ap.plot_disparity_all(bias_df, metrics=['precision_disparity'], significance_alpha=0.05)
